# %% [markdown]
# ## [문제]
# - 질문: 사용자에게 받기
# - 대화 내역을 저장: ConversationBufferMemory()

# %%
from langchain_openai import ChatOpenAI
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.memory import ConversationBufferMemory
from dotenv import load_dotenv


load_dotenv()

llm = ChatOpenAI(
    model='gpt-4.1-nano',
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

memory = ConversationBufferMemory(return_messages=True)

prompt = ChatPromptTemplate.from_messages([
    ('system', '당신은 한국의 유명한 시인입니다.'),
    MessagesPlaceholder('history'),
    ('user', '{input}')
])

chain = prompt | llm
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_8480\3166758201.py:16: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(return_messages=True)

# %%
query = input('질문하세요... >> ')

ai_message = chain.invoke({
    'input': query,
    'history': memory.chat_memory.messages
})

memory.save_context(
    inputs={'input': query},
    outputs={'output': ai_message.content}
)

memory
# Out:
# 푸른 하늘 위로 날아오르는 꿈
# 구름이 춤추는 즐거운 무대 위에서
# 햇살 가득 품에 안고 웃으며 걷고
# 바람은 속삭이며 기분을 돋우네
#
# 날개 없는 새들도 희망 노래 부르고
# 무지개는 꿈을 담아 웃음을 선사해
# 맑은 하늘 아래서 오늘도 나는
# 행복한 하루를 만끽하네
# ConversationBufferMemory(chat_memory=InMemoryChatMessageHistory(messages=[HumanMessage(content='하늘을 주제로 밝고 경쾌한 시 한 편 부탁해요.', additional_kwargs={}, response_metadata={}), AIMessage(content='푸른 하늘 위로 날아오르는 꿈  \n구름이 춤추는 즐거운 무대 위에서  \n햇살 가득 품에 안고 웃으며 걷고  \n바람은 속삭이며 기분을 돋우네  \n\n날개 없는 새들도 희망 노래 부르고  \n무지개는 꿈을 담아 웃음을 선사해  \n맑은 하늘 아래서 오늘도 나는  \n행복한 하루를 만끽하네', additional_kwargs={}, response_metadata={})]), return_messages=True)

# %%
ai_message
# Out:
# AIMessage(content='푸른 하늘 위로 날아오르는 꿈  \n구름이 춤추는 즐거운 무대 위에서  \n햇살 가득 품에 안고 웃으며 걷고  \n바람은 속삭이며 기분을 돋우네  \n\n날개 없는 새들도 희망 노래 부르고  \n무지개는 꿈을 담아 웃음을 선사해  \n맑은 하늘 아래서 오늘도 나는  \n행복한 하루를 만끽하네', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_17d1f82c3e'}, id='run-ed89a5e4-2cff-4c0c-a61e-d6bf9a9f39cb-0')

# %%
# %whos
# Out:
# Variable                         Type                        Data/Info
# ----------------------------------------------------------------------
# ChatOpenAI                       ModelMetaclass              <class 'langchain_openai.<...>_models.base.ChatOpenAI'>
# ChatPromptTemplate               ModelMetaclass              <class 'langchain_core.pr<...>chat.ChatPromptTemplate'>
# ConversationBufferMemory         ModelMetaclass              <class 'langchain.memory.<...>onversationBufferMemory'>
# MessagesPlaceholder              ModelMetaclass              <class 'langchain_core.pr<...>hat.MessagesPlaceholder'>
# StreamingStdOutCallbackHandler   type                        <class 'langchain_core.ca<...>ngStdOutCallbackHandler'>
# ai_message                       AIMessage                   content='푸른 하늘의 노래  \n\n높<...>4e62-acd4-53fc2d9884e4-0'
# chain                            RunnableSequence            first=ChatPromptTemplate(<...>******'), streaming=True)
# input                            str                         하늘을 주제로 시 한 편 써줘!
# llm                              ChatOpenAI                  callbacks=[<langchain_cor<...>********') streaming=True
# load_dotenv                      function                    <function load_dotenv at 0x000001F7587EF910>
# memory                           ConversationBufferMemory    chat_memory=InMemoryChatM<...>=[]) return_messages=True
# prompt                           ChatPromptTemplate          input_variables=['history<...>), additional_kwargs={})]

# %%
del input

# %%
# %whos
# Out:
# Variable                         Type                        Data/Info
# ----------------------------------------------------------------------
# ChatOpenAI                       ModelMetaclass              <class 'langchain_openai.<...>_models.base.ChatOpenAI'>
# ChatPromptTemplate               ModelMetaclass              <class 'langchain_core.pr<...>chat.ChatPromptTemplate'>
# ConversationBufferMemory         ModelMetaclass              <class 'langchain.memory.<...>onversationBufferMemory'>
# MessagesPlaceholder              ModelMetaclass              <class 'langchain_core.pr<...>hat.MessagesPlaceholder'>
# StreamingStdOutCallbackHandler   type                        <class 'langchain_core.ca<...>ngStdOutCallbackHandler'>
# ai_message                       AIMessage                   content='푸른 하늘의 노래  \n\n높<...>4e62-acd4-53fc2d9884e4-0'
# chain                            RunnableSequence            first=ChatPromptTemplate(<...>******'), streaming=True)
# llm                              ChatOpenAI                  callbacks=[<langchain_cor<...>********') streaming=True
# load_dotenv                      function                    <function load_dotenv at 0x000001F7587EF910>
# memory                           ConversationBufferMemory    chat_memory=InMemoryChatM<...>=[]) return_messages=True
# prompt                           ChatPromptTemplate          input_variables=['history<...>), additional_kwargs={})]

# %%
# %whos
# Out:
# Variable                         Type                        Data/Info
# ----------------------------------------------------------------------
# ChatOpenAI                       ModelMetaclass              <class 'langchain_openai.<...>_models.base.ChatOpenAI'>
# ChatPromptTemplate               ModelMetaclass              <class 'langchain_core.pr<...>chat.ChatPromptTemplate'>
# ConversationBufferMemory         ModelMetaclass              <class 'langchain.memory.<...>onversationBufferMemory'>
# MessagesPlaceholder              ModelMetaclass              <class 'langchain_core.pr<...>hat.MessagesPlaceholder'>
# StreamingStdOutCallbackHandler   type                        <class 'langchain_core.ca<...>ngStdOutCallbackHandler'>
# ai_message                       AIMessage                   content='푸른 하늘 그 너머에  \n수<...>432e-bd8d-03ed20fb427a-0'
# chain                            RunnableSequence            first=ChatPromptTemplate(<...>******'), streaming=True)
# input                            str                         하늘을 주제로 서정적인 시 한 편 부탁해요.
# llm                              ChatOpenAI                  callbacks=[<langchain_cor<...>********') streaming=True
# load_dotenv                      function                    <function load_dotenv at 0x000001F7587EF910>
# memory                           ConversationBufferMemory    chat_memory=InMemoryChatM<...>=[]) return_messages=True
# prompt                           ChatPromptTemplate          input_variables=['history<...>), additional_kwargs={})]

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
from langchain_core.output_parsers import StrOutputParser

chain2 = prompt | llm | StrOutputParser()
# chain2

# %%
query = input('질문하세요... >> ')

ai_message2 = chain2.invoke({
    'input': query,
    'history': memory.chat_memory.messages
})
ai_message2
# Out:
# 별빛 가득한 밤하늘 속에 떠도는 꿈
# 은은한 빛결 따라 은밀히 흐르네
# 구름 속으로 사라지는 속삭임은
# 아득한 세상과 마음을 연결하네
#
# 몽환의 강가에서 잊혀진 노래를 듣고
# 달빛은 은은히 미로 같은 길을 비추네
# 꿈의 숲에는 신비한 이들이 살며
# 무한한 가능성의 문을 열어주네
#
# 깊은 밤, 눈을 감으면 떠오르는 저 넓은 세계—
# 그곳에서 나는 또 다른 나를 만나러 떠나네
# '별빛 가득한 밤하늘 속에 떠도는 꿈  \n은은한 빛결 따라 은밀히 흐르네  \n구름 속으로 사라지는 속삭임은  \n아득한 세상과 마음을 연결하네  \n\n몽환의 강가에서 잊혀진 노래를 듣고  \n달빛은 은은히 미로 같은 길을 비추네  \n꿈의 숲에는 신비한 이들이 살며  \n무한한 가능성의 문을 열어주네  \n\n깊은 밤, 눈을 감으면 떠오르는 저 넓은 세계—  \n그곳에서 나는 또 다른 나를 만나러 떠나네'

# %%
type(ai_message2)
# Out:
# str

# %%
memory.save_context(
    inputs={'input': query},
    outputs={'output': ai_message2}
)

memory
# Out:
# ConversationBufferMemory(chat_memory=InMemoryChatMessageHistory(messages=[HumanMessage(content='하늘을 주제로 밝고 경쾌한 시 한 편 부탁해요.', additional_kwargs={}, response_metadata={}), AIMessage(content='푸른 하늘 위로 날아오르는 꿈  \n구름이 춤추는 즐거운 무대 위에서  \n햇살 가득 품에 안고 웃으며 걷고  \n바람은 속삭이며 기분을 돋우네  \n\n날개 없는 새들도 희망 노래 부르고  \n무지개는 꿈을 담아 웃음을 선사해  \n맑은 하늘 아래서 오늘도 나는  \n행복한 하루를 만끽하네', additional_kwargs={}, response_metadata={}), HumanMessage(content='꿈을 주제로 신비스럽고 몽환적인 시 한 편 부탁합니다.', additional_kwargs={}, response_metadata={}), AIMessage(content='별빛 가득한 밤하늘 속에 떠도는 꿈  \n은은한 빛결 따라 은밀히 흐르네  \n구름 속으로 사라지는 속삭임은  \n아득한 세상과 마음을 연결하네  \n\n몽환의 강가에서 잊혀진 노래를 듣고  \n달빛은 은은히 미로 같은 길을 비추네  \n꿈의 숲에는 신비한 이들이 살며  \n무한한 가능성의 문을 열어주네  \n\n깊은 밤, 눈을 감으면 떠오르는 저 넓은 세계—  \n그곳에서 나는 또 다른 나를 만나러 떠나네', additional_kwargs={}, response_metadata={})]), return_messages=True)
