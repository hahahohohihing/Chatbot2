# %% [markdown]
# # [문제]
# - model: gpt-4.1-nano
# - 스트리밍 활성화
# - single-turn 대화
# - role: system    -> 역할 부여
#   role: user      -> 질문: 사용자에게 받을 것
#   role: assistant -> 답변: LLM 모델 답변

# %%
## 1. 모듈(파일) 읽어오기
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

## 2. 환경변수에 설정된 값 읽어오기
load_dotenv()

## 3. ChatOpenAI 인스턴스 생성
llm = ChatOpenAI(
  model='gpt-4.1-nano',
  streaming=True,
  callbacks=[StreamingStdOutCallbackHandler()],
)

## OpenAI Native Format ############################################
## 4. system prompt 작성

## '온라인 마케팅을 기획하려고 해. 시작을 어떻게 해야 할까?'
query = input('질문을 입력하세요 >> ')

message = [
  ## system: 모델의 역할과 스타일 지정
  {'role': 'system', 'content': '너는 20년차 광고 기획자야. 질문에 프로답게 상세하고 친절하게 답변해줘.'},
  ## user: 실제 사용자의 질문
  {'role': 'user', 'content': query}
]

ai_message = llm.invoke(message)
ai_message
# Out:
# 온라인 마케팅을 처음 시작하는 단계에서 체계적인 계획과 전략이 매우 중요합니다. 다음은 온라인 마케팅 기획을 효과적으로 시작하는 방법에 대한 상세한 가이드입니다.
#
# 1. 목표 설정
# - 구체적이고 측정 가능한 목표를 세우세요.
# 예: 브랜드 인지도 향상, 웹사이트 방문자 수 증가, 판매량 증대, 고객 문의 수 증가 등.
# - 목표는 SMART 원칙(구체적 Specific, 측정 가능 Measurable, 달성 가능 Achievable, 관련성 Relevant, 시간 제한 Time-bound)에 따라 세우는 것이 좋습니다.
#
# 2. 대상 고객 분석
# - 타깃 고객의 연령, 성별, 지역, 관심사, 행동 패턴 등을 조사하세요.
# - 고객 페르소나(Persona)를 만들어 고객의 니즈와 기대를 명확히 파악하는 것이 효과적입니다.
#
# 3. 경쟁사 분석
# - 경쟁사들이 어떤 온라인 채널과 콘텐츠를 활용하는지 조사하세요.
# - 강점과 약점을 분석하여 차별화 포인트를 도출하세요.
#
# 4. 채널 선정
# - 대상 고객과 목표에 맞는 채널을 선택하세요.
# 가장 흔히 사용하는 온라인 채널은 다음과 같습니다.
#   - 검색엔진 최적화(SEO), 검색 광고(Google Ads)
#   - SNS 플랫폼(인스타그램, 페이스북, 유튜브, 틱톡 등)
#   - 이메일 마케팅
#   - 콘텐츠 마케팅(블로그, 영상, 인포그래픽 등)
#   - 온라인 커뮤니티 및 포럼
#
# 5. 콘텐츠 전략 수립
# - 고객 가치와 니즈를 반영한 콘텐츠를 기획하세요.
# - 콘텐츠 유형별(영상, 이미지, 글) 제작 계획을 세우고, 일정과 예산을 확정하세요.
#
# 6. 예산 배분과 일정 계획
# - 전체 예산을 정하고, 채널별, 콘텐츠별로 예산을 배분하세요.
# - 실행 일정표를 만들고, 각 단계별 목표 일정을 명확히 하세요.
#
# 7. 성과 측정 및 피드백
# - KPI(Key Performance Indicators)를 설정해 성과를 정기적으로 점검하세요.
# - 구글 애널리틱스, SNS 분석 도구 등으로 데이터를 수집하고, 전략을 조정하세요.
#
# 8. 실행과 모니터링
# - 계획에 따라 콘텐츠를 제작, 게시하고 피드백을 수집합니다.
# - 지속적으로 성과를 분석하여 캠페인을 최적화하세요.
#
# 추가로, 온라인 마케팅은 한 번의 실행이 아니라 지속적이고 체계적인 관리가 필요하니, 정기적인 분석과 개선을 잊지 마세요. 혹시 구체적인 산업군이나 타겟 고객, 또는 예산 규모 등에 대해 더 말씀해주시면 맞춤형 전략도 제안드릴 수 있습니다.
# AIMessage(content='온라인 마케팅을 처음 시작하는 단계에서 체계적인 계획과 전략이 매우 중요합니다. 다음은 온라인 마케팅 기획을 효과적으로 시작하는 방법에 대한 상세한 가이드입니다.\n\n1. 목표 설정\n- 구체적이고 측정 가능한 목표를 세우세요.\n예: 브랜드 인지도 향상, 웹사이트 방문자 수 증가, 판매량 증대, 고객 문의 수 증가 등.\n- 목표는 SMART 원칙(구체적 Specific, 측정 가능 Measurable, 달성 가능 Achievable, 관련성 Relevant, 시간 제한 Time-bound)에 따라 세우는 것이 좋습니다.\n\n2. 대상 고객 분석\n- 타깃 고객의 연령, 성별, 지역, 관심사, 행동 패턴 등을 조사하세요.\n- 고객 페르소나(Persona)를 만들어 고객의 니즈와 기대를 명확히 파악하는 것이 효과적입니다.\n\n3. 경쟁사 분석\n- 경쟁사들이 어떤 온라인 채널과 콘텐츠를 활용하는지 조사하세요.\n- 강점과 약점을 분석하여 차별화 포인트를 도출하세요.\n\n4. 채널 선정\n- 대상 고객과 목표에 맞는 채널을 선택하세요.\n가장 흔히 사용하는 온라인 채널은 다음과 같습니다.\n  - 검색엔진 최적화(SEO), 검색 광고(Google Ads)\n  - SNS 플랫폼(인스타그램, 페이스북, 유튜브, 틱톡 등)\n  - 이메일 마케팅\n  - 콘텐츠 마케팅(블로그, 영상, 인포그래픽 등)\n  - 온라인 커뮤니티 및 포럼\n\n5. 콘텐츠 전략 수립\n- 고객 가치와 니즈를 반영한 콘텐츠를 기획하세요.\n- 콘텐츠 유형별(영상, 이미지, 글) 제작 계획을 세우고, 일정과 예산을 확정하세요.\n\n6. 예산 배분과 일정 계획\n- 전체 예산을 정하고, 채널별, 콘텐츠별로 예산을 배분하세요.\n- 실행 일정표를 만들고, 각 단계별 목표 일정을 명확히 하세요.\n\n7. 성과 측정 및 피드백\n- KPI(Key Performance Indicators)를 설정해 성과를 정기적으로 점검하세요.\n- 구글 애널리틱스, SNS 분석 도구 등으로 데이터를 수집하고, 전략을 조정하세요.\n\n8. 실행과 모니터링\n- 계획에 따라 콘텐츠를 제작, 게시하고 피드백을 수집합니다.\n- 지속적으로 성과를 분석하여 캠페인을 최적화하세요.\n\n추가로, 온라인 마케팅은 한 번의 실행이 아니라 지속적이고 체계적인 관리가 필요하니, 정기적인 분석과 개선을 잊지 마세요. 혹시 구체적인 산업군이나 타겟 고객, 또는 예산 규모 등에 대해 더 말씀해주시면 맞춤형 전략도 제안드릴 수 있습니다.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_8fd43718b3'}, id='run-3f7279c1-7559-48b0-a55e-9385090feba5-0')

# %%
ai_message.content
# Out:
# '온라인 마케팅을 처음 시작하는 단계에서 체계적인 계획과 전략이 매우 중요합니다. 다음은 온라인 마케팅 기획을 효과적으로 시작하는 방법에 대한 상세한 가이드입니다.\n\n1. 목표 설정\n- 구체적이고 측정 가능한 목표를 세우세요.\n예: 브랜드 인지도 향상, 웹사이트 방문자 수 증가, 판매량 증대, 고객 문의 수 증가 등.\n- 목표는 SMART 원칙(구체적 Specific, 측정 가능 Measurable, 달성 가능 Achievable, 관련성 Relevant, 시간 제한 Time-bound)에 따라 세우는 것이 좋습니다.\n\n2. 대상 고객 분석\n- 타깃 고객의 연령, 성별, 지역, 관심사, 행동 패턴 등을 조사하세요.\n- 고객 페르소나(Persona)를 만들어 고객의 니즈와 기대를 명확히 파악하는 것이 효과적입니다.\n\n3. 경쟁사 분석\n- 경쟁사들이 어떤 온라인 채널과 콘텐츠를 활용하는지 조사하세요.\n- 강점과 약점을 분석하여 차별화 포인트를 도출하세요.\n\n4. 채널 선정\n- 대상 고객과 목표에 맞는 채널을 선택하세요.\n가장 흔히 사용하는 온라인 채널은 다음과 같습니다.\n  - 검색엔진 최적화(SEO), 검색 광고(Google Ads)\n  - SNS 플랫폼(인스타그램, 페이스북, 유튜브, 틱톡 등)\n  - 이메일 마케팅\n  - 콘텐츠 마케팅(블로그, 영상, 인포그래픽 등)\n  - 온라인 커뮤니티 및 포럼\n\n5. 콘텐츠 전략 수립\n- 고객 가치와 니즈를 반영한 콘텐츠를 기획하세요.\n- 콘텐츠 유형별(영상, 이미지, 글) 제작 계획을 세우고, 일정과 예산을 확정하세요.\n\n6. 예산 배분과 일정 계획\n- 전체 예산을 정하고, 채널별, 콘텐츠별로 예산을 배분하세요.\n- 실행 일정표를 만들고, 각 단계별 목표 일정을 명확히 하세요.\n\n7. 성과 측정 및 피드백\n- KPI(Key Performance Indicators)를 설정해 성과를 정기적으로 점검하세요.\n- 구글 애널리틱스, SNS 분석 도구 등으로 데이터를 수집하고, 전략을 조정하세요.\n\n8. 실행과 모니터링\n- 계획에 따라 콘텐츠를 제작, 게시하고 피드백을 수집합니다.\n- 지속적으로 성과를 분석하여 캠페인을 최적화하세요.\n\n추가로, 온라인 마케팅은 한 번의 실행이 아니라 지속적이고 체계적인 관리가 필요하니, 정기적인 분석과 개선을 잊지 마세요. 혹시 구체적인 산업군이나 타겟 고객, 또는 예산 규모 등에 대해 더 말씀해주시면 맞춤형 전략도 제안드릴 수 있습니다.'
